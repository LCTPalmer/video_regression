# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os
os.chdir('D:/projects/Data Scientist Role')

# %%
df = pd.read_csv('Q2/TrendData.csv')

# %%
df.head()
# Out:
#          Date   Value
# 0  07/04/2014  137209
# 1  04/04/2014  137639
# 2  03/04/2014  137876
# 3  02/04/2014  137795
# 4  01/04/2014  137623

# %%
df['Date'].count()
# Out:
# 3806

# %%
df.plot(x='Date', y='Value', figsize=(12,10))
